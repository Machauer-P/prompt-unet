# %% [markdown]
# # PromptUNet Test Pipeline Runner
# This notebook allows you to configure and run the modularized test pipeline for PromptUNet models natively. <br>
# Just copy, rename and test new/other models.

# %%
import os
import sys

sys.path.append(os.path.join(os.getcwd(), '..', '..'))

from utils.augmentations import PromptUNetAugmenter
from evaluation.eval_prompt_unet.eval_p_unet_pipeline import PromptUNetTester
# Out:
# WARNING:tensorflow:From c:\Users\Paul\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\Paul\anaconda3\Lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From c:\Users\Paul\anaconda3\Lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.

# %% [markdown]
# ### 1. Configure Testing Parameters

# %%
dimensions = ['x', 'y', 'z'] 
offsets = [5, 10, 20]
models = [
    'p_unet_21.keras',
    'p_unet_272.keras',
    'p_unet_273.keras',
    'p_unet_282.keras',
    'p_unet_283.keras'
]


max_data_points = 50
models_dir = "training/"

# You can define active augmentations here. Example: augmentations = [{'name': 'add_noise'}]
augmentations = []

# %% [markdown]
# ### 2. Run Pipeline

# %% [markdown]
# #### MRI

# %%
dataset_path = ["data/test_data/HanSeg_MRI.pkl"]

cropping = True
min_crop_size = 0.4

# Initialize tester
tester = PromptUNetTester(
    dataset_path=dataset_path,
    models_dir=models_dir,
    augmentations=augmentations,
    max_data_points=max_data_points
)

# Execute full validation loop (outputs and plots will be rendered sequentially)
results = tester.run_pipeline(
    dimensions=dimensions, 
    offsets=offsets, 
    models=models, 
    threshold=0.45,
    cropping=cropping,
    min_crop_size=min_crop_size,
    num_visualize=2
)
# Out:
# Loading PKL dataset(s)…
# Loaded 4 PIDs from C:\Users\Paul\Desktop\Studium\prompt-unet\data\test_data\HanSeg_MRI.pkl
#
# Final dataset size: 4 patients.
#
#
# ...
#    EVALUATING OFFSET: 5 | AXIS: ['x', 'y', 'z']
# ...
#
# Creating new Data Points ...
# It took 3 seconds
#
# --- [SECTION 1: METRICS] ---
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
#
# Testing for p_unet_21.keras took 12.0 seconds
# [p_unet_21.keras] -> Avg Dice: 0.888
#
# Testing for p_unet_272.keras took 10.0 seconds
# [p_unet_272.keras] -> Avg Dice: 0.846
#
# Testing for p_unet_273.keras took 10.0 seconds
# [p_unet_273.keras] -> Avg Dice: 0.875
#
# Testing for p_unet_282.keras took 13.0 seconds
# [p_unet_282.keras] -> Avg Dice: 0.876
#
# Testing for p_unet_283.keras took 11.0 seconds
# [p_unet_283.keras] -> Avg Dice: 0.858
#
# --- [SECTION 2: VISUALIZATIONS] ---
#
# ...

# %% [markdown]
# #### CT

# %%
dataset_path = ["data/test_data/HanSeg_CT.pkl"]

cropping = True
min_crop_size = 0.4

# Initialize tester
tester = PromptUNetTester(
    dataset_path=dataset_path,
    models_dir=models_dir,
    augmentations=augmentations,
    max_data_points=max_data_points
)

# Execute full validation loop (outputs and plots will be rendered sequentially)
results = tester.run_pipeline(
    dimensions=dimensions, 
    offsets=offsets, 
    models=models, 
    threshold=0.45,
    cropping=cropping,
    min_crop_size=min_crop_size,
    num_visualize=2
)
# Out:
# Loading PKL dataset(s)…
# Loaded 4 PIDs from C:\Users\Paul\Desktop\Studium\prompt-unet\data\test_data\HanSeg_CT.pkl
#
# Final dataset size: 4 patients.
#
#
# ...
#    EVALUATING OFFSET: 5 | AXIS: ['y', 'z', 'x']
# ...
#
# Creating new Data Points ...
# It took 3 seconds
#
# --- [SECTION 1: METRICS] ---
#
# Testing for p_unet_21.keras took 11.0 seconds
# [p_unet_21.keras] -> Avg Dice: 0.806
#
# Testing for p_unet_272.keras took 10.0 seconds
# [p_unet_272.keras] -> Avg Dice: 0.688
#
# Testing for p_unet_273.keras took 12.0 seconds
# [p_unet_273.keras] -> Avg Dice: 0.822
#
# Testing for p_unet_282.keras took 13.0 seconds
# [p_unet_282.keras] -> Avg Dice: 0.802
#
# Testing for p_unet_283.keras took 13.0 seconds
# [p_unet_283.keras] -> Avg Dice: 0.817
#
# --- [SECTION 2: VISUALIZATIONS] ---
#
# >> Visualizing predictions for: p_unet_21.keras (Threshold: 0.45)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Dice: 0.802
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Dice: 0.451
#
#
# ...
